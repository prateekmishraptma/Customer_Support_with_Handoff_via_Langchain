# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (1.2.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.9 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.2.9)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.7 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.0.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (0.6.9)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (9.1.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (4.12.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.2.9->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.9->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (0.3.4)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.7->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.11.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (4.8.0)
# Requirement already satisfied: certifi in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (1.0.7)
# Requirement already satisfied: idna in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.9->langchain) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\prate\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.7->langchain) (1.3.1)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
import os

os.environ["OPENAI_API_KEY"] = "<paste-your-openai-key>"
model = ChatOpenAI(model="gpt-4.1")

# %%
from langchain.agents import AgentState
from typing_extensions import NotRequired
from typing import Literal

SupportStep = Literal["warranty_collector" , "issue_classifier", "resolution_specialist"]

class SupportState(AgentState):
    """State for customer support workflow."""
    current_step: NotRequired[SupportStep]
    warranty_status: NotRequired[Literal["in_warranty", "out_of_warranty"]]
    issue_type: NotRequired[Literal["hardware","software"]]

# %%
from langchain.tools import tool, ToolRuntime
from langchain.messages import ToolMessage
from langgraph.types import Command

@tool
def record_warranty_status(
    status: Literal["in_warranty","out_of_warranty"],
    runtime: ToolRuntime[None, SupportState],
) -> Command:
    """Record the customer's warranty status and transition to issue classification"""
    return Command(
        update={
            "messages": [
                ToolMessage(
                    content=f"Warranty status recorded as: {status}",
                    tool_call_id=runtime.tool_call_id,
                )
            ],
            "warranty_status": status,
            "current_step": "issue_classifier",
        }
    )

@tool
def record_issue_type(
    issue_type: Literal["hardware","software"],
    runtime: ToolRuntime[None, SupportState],
) -> Command:
    """Record the type of issues and trasition to resolution specialist."""
    return Command(
        update={
            "messages" : [
                ToolMessage(
                    content=f"issue type recorded as: {issue_type}",
                    tool_call_id=runtime.tool_call_id,
                )
            ],
            "issue_type": issue_type,
            "current_step": "resolution_specialist",
        }
    )

@tool
def esclate_to_human(reason: str) -> str:
    """Esclate the case to a human support specialist."""
    return f"Esclating to human support. Reason: {reason}"

@tool
def provide_resolution(solution: str) -> str:
    """Provide a solution to the customer's issue."""
    return f"Solution provided: {solution}"

# %%
# Define prompts as constants for easy reference
WARRANTY_COLLECTOR_PROMPT = """You are a customer support agent helping with device issues.

CURRENT STAGE: Warranty verification

At this step, you need to:
1. Greet the customer warmly
2. Ask if their device is under warranty
3. Use record_warranty_status to record their response and move to the next step

Be conversational and friendly. Don't ask multiple questions at once."""

ISSUE_CLASSIFIER_PROMPT = """You are a customer support agent helping with device issues.

CURRENT STAGE: Issue classification
CUSTOMER INFO: Warranty status is {warranty_status}

At this step, you need to:
1. Ask the customer to describe their issue
2. Determine if it's a hardware issue (physical damage, broken parts) or software issue (app crashes, performance)
3. Use record_issue_type to record the classification and move to the next step

If unclear, ask clarifying questions before classifying."""

RESOLUTION_SPECIALIST_PROMPT = """You are a customer support agent helping with device issues.

CURRENT STAGE: Resolution
CUSTOMER INFO: Warranty status is {warranty_status}, issue type is {issue_type}

At this step, you need to:
1. For SOFTWARE issues: provide troubleshooting steps using provide_solution
2. For HARDWARE issues:
   - If IN WARRANTY: explain warranty repair process using provide_solution
   - If OUT OF WARRANTY: escalate_to_human for paid repair options

Be specific and helpful in your solutions."""

# %%
STEP_CONFIG = {
    "waranty_collector": {
        "prompt" : WARRANTY_COLLECTOR_PROMPT,
        "tools": [record_warranty_status],
        "requires": [],
    },
    "issue_classifier": {
        "prompt" : ISSUE_CLASSIFIER_PROMPT,
        "tools": [record_issue_type],
        "requires": ["warranty_status"],
    },
    "resolution_specialist": {
        "prompt": RESOLUTION_SPECIALIST_PROMPT,
        "tools": [provide_resolution, esclate_to_human],
        "requires": ["warranty_status","issue_type"],
    },
}

# %%
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
from typing import Callable

@wrap_model_call
def apply_step_config(
    request: ModelRequest,
    handler: Callable[[ModelRequest], ModelResponse],
) -> ModelResponse:
    """Configure agent behaviour based on the current step."""
    current_step = request.state.get("current_step", "warranty_collector")

    stage_config = STEP_CONFIG[current_step]

    for key in stage_config["requires"]:
        if request.state.get(key) is None:
            raise ValueError(f"{key} must be set before reaching {current_step}")

    system_prompt = stage_config["prompt"].format(**request.state)

    request = request.override(
        system_prompt=system_prompt,
        tools=stage_config["tools"],
    )

    return handler(request)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

all_tools = [
    record_warranty_status,
    record_issue_type,
    provide_resolution,
    esclate_to_human,
]

agent = create_agent(
    model,
    tools=all_tools,
    state_schema=SupportState,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage
import uuid

thread_id = str(uuid.uuid4())
config = {"configurable": {"thread_id": thread_id}}

print("====Turn 1: Warranty Collection ====")
result = agent.invoke(
    {"messages": [HumanMessage("Hi My phone screen is cracked")]},
    config
)

for msg in result["messages"]:
    msg.pretty_print()


print("\n=== Turn 2: Warranty Response ===")
result = agent.invoke(
    {"messages": [HumanMessage("yes, it's still under warranty")]},
    config
)

for msg in result["messages"]:
    msg.pretty_print()
print(f"Current Step: {result.get("current_step")}")


print("\n=== Turn 3: Issue Description ===")
result = agent.invoke(
    {"messages": [HumanMessage("The screen is physically cracked from dropping it")]},
    config
)

for msg in result["messages"]:
    msg.pretty_print()
print(f"Current Step: {result.get("current_step")}")

print("\n=== Turn 4: Resolution ===")
result = agent.invoke(
    {"messages": [HumanMessage("What should I do?")]},
    config
)

for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ====Turn 1: Warranty Collection ====
# ================================ Human Message =================================
#
# Hi My phone screen is cracked
# ================================== Ai Message ==================================
#
# I'm sorry to hear that your phone screen is cracked. I can help you with the next steps. First, could you please let me know if your phone is still under warranty? This will help determine the best solution for your situation.
#
# === Turn 2: Warranty Response ===
# ================================ Human Message =================================
#
# Hi My phone screen is cracked
# ================================== Ai Message ==================================
#
# I'm sorry to hear that your phone screen is cracked. I can help you with the next steps. First, could you please let me know if your phone is still under warranty? This will help determine the best solution for your situation.
# ================================ Human Message =================================
#
# yes, it's still under warranty
# ================================== Ai Message ==================================
# Tool Calls:
#   record_warranty_status (call_o1Fmw5IrYsrysxDKppUtUbt3)
#  Call ID: call_o1Fmw5IrYsrysxDKppUtUbt3
#   Args:
#     status: in_warranty
# ================================= Tool Message =================================
# Name: record_warranty_status
#
# Warranty status recorded as: in_warranty
# ================================== Ai Message ==================================
#
# Thank you for confirming that your phone is still under warranty. To assist you further, could you please specify if your cracked screen happened due to accidental damage (like a drop), or if it seems like a defect (it cracked on its own)? This information will help determine if the repair is covered under warranty.
#
# Additionally, let me know your phone model for accurate assistance.
# Current Step: issue_classifier
#
# === Turn 3: Issue Description ===
# ================================ Human Message =================================
#
# Hi My phone screen is cracked
# ================================== Ai Message ==================================
#
# I'm sorry to hear that your phone screen is cracked. I can help you with the next steps. First, could you please let me know if your phone is still under warranty? This will help determine the best solution for your situation.
# ================================ Human Message =================================
#
# yes, it's still under warranty
# ================================== Ai Message ==================================
# Tool Calls:
#   record_warranty_status (call_o1Fmw5IrYsrysxDKppUtUbt3)
#  Call ID: call_o1Fmw5IrYsrysxDKppUtUbt3
#   Args:
#     status: in_warranty
# ================================= Tool Message =================================
# Name: record_warranty_status
#
# Warranty status recorded as: in_warranty
# ================================== Ai Message ==================================
#
# Thank you for confirming that your phone is still under warranty. To assist you further, could you please specify if your cracked screen happened due to accidental damage (like a drop), or if it seems like a defect (it cracked on its own)? This information will help determine if the repair is covered under warranty.
#
# Additionally, let me know your phone model for accurate assistance.
# ================================ Human Message =================================
#
# The screen is physically cracked from dropping it
# ================================== Ai Message ==================================
# Tool Calls:
#   record_issue_type (call_gqSVvuAWb1WSK4Z7CCASCxms)
#  Call ID: call_gqSVvuAWb1WSK4Z7CCASCxms
#   Args:
#     issue_type: hardware
# ================================= Tool Message =================================
# Name: record_issue_type
#
# issue type recorded as: hardware
# ================================== Ai Message ==================================
#
# Since the screen crack happened due to accidental damage (dropping the phone), this is considered a hardware issue. While your phone is under warranty, most standard warranties do not cover accidental physical damage but some extended or premium warranties (like AppleCare+ or similar) might.
#
# Could you please tell me your phone brand and model, as well as if you purchased any additional accidental damage coverage or service plan? This will help me provide the most accurate resolution and next steps for your repair or replacement options.
# Current Step: resolution_specialist
#
# === Turn 4: Resolution ===
# ================================ Human Message =================================
#
# Hi My phone screen is cracked
# ================================== Ai Message ==================================
#
# I'm sorry to hear that your phone screen is cracked. I can help you with the next steps. First, could you please let me know if your phone is still under warranty? This will help determine the best solution for your situation.
# ================================ Human Message =================================
#
# yes, it's still under warranty
# ================================== Ai Message ==================================
# Tool Calls:
#   record_warranty_status (call_o1Fmw5IrYsrysxDKppUtUbt3)
#  Call ID: call_o1Fmw5IrYsrysxDKppUtUbt3
#   Args:
#     status: in_warranty
# ================================= Tool Message =================================
# Name: record_warranty_status
#
# Warranty status recorded as: in_warranty
# ================================== Ai Message ==================================
#
# Thank you for confirming that your phone is still under warranty. To assist you further, could you please specify if your cracked screen happened due to accidental damage (like a drop), or if it seems like a defect (it cracked on its own)? This information will help determine if the repair is covered under warranty.
#
# Additionally, let me know your phone model for accurate assistance.
# ================================ Human Message =================================
#
# The screen is physically cracked from dropping it
# ================================== Ai Message ==================================
# Tool Calls:
#   record_issue_type (call_gqSVvuAWb1WSK4Z7CCASCxms)
#  Call ID: call_gqSVvuAWb1WSK4Z7CCASCxms
#   Args:
#     issue_type: hardware
# ================================= Tool Message =================================
# Name: record_issue_type
#
# issue type recorded as: hardware
# ================================== Ai Message ==================================
#
# Since the screen crack happened due to accidental damage (dropping the phone), this is considered a hardware issue. While your phone is under warranty, most standard warranties do not cover accidental physical damage but some extended or premium warranties (like AppleCare+ or similar) might.
#
# Could you please tell me your phone brand and model, as well as if you purchased any additional accidental damage coverage or service plan? This will help me provide the most accurate resolution and next steps for your repair or replacement options.
# ================================ Human Message =================================
#
# What should I do?
# ================================== Ai Message ==================================
# Tool Calls:
#   provide_resolution (call_2EsHHXbmxdP7QvbM52fPpPHT)
#  Call ID: call_2EsHHXbmxdP7QvbM52fPpPHT
#   Args:
#     solution: Since your phone is still under warranty but the cracked screen is due to accidental damage (from dropping it), most standard warranties may not cover this type of repair. Here are your next steps:
#
# 1. Check if you have accidental damage coverage (such as AppleCare+, Samsung Care+, or any extended warranty plan). If you do, contact your warranty provider or visit an authorized service center to initiate a repair or replacement.
#
# 2. If you do not have accidental damage coverage, you can still get the screen repaired through an authorized service provider, but this may incur a repair fee.
#
# 3. Back up your data before handing over your device for repair.
#
# Would you like help finding the nearest authorized service center or information on starting a repair claim online?
# ================================= Tool Message =================================
# Name: provide_resolution
#
# Solution provided: Since your phone is still under warranty but the cracked screen is due to accidental damage (from dropping it), most standard warranties may not cover this type of repair. Here are your next steps:
#
# 1. Check if you have accidental damage coverage (such as AppleCare+, Samsung Care+, or any extended warranty plan). If you do, contact your warranty provider or visit an authorized service center to initiate a repair or replacement.
#
# 2. If you do not have accidental damage coverage, you can still get the screen repaired through an authorized service provider, but this may incur a repair fee.
#
# 3. Back up your data before handing over your device for repair.
#
# Would you like help finding the nearest authorized service center or information on starting a repair claim online?
# ================================== Ai Message ==================================
#
# Since your phone is still under warranty but the cracked screen is due to accidental damage (from dropping it), most standard warranties may not cover this type of repair. Here’s what you should do next:
#
# 1. Check if you have accidental damage coverage (like AppleCare+, Samsung Care+, or a similar extended warranty). If you do, contact your warranty provider or visit an authorized service center to begin a repair or replacement.
#
# 2. If you don’t have accidental damage coverage, you can still have the screen repaired at an authorized service center, but this will likely incur a repair fee.
#
# 3. Back up your data before handing over your device for repair.
#
# Would you like assistance finding the nearest authorized service center or instructions on starting a repair claim online? Let me know how you’d like to proceed!
